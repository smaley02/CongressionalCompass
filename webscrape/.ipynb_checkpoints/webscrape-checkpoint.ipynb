# %%
import os
import requests
from dotenv import load_dotenv

# Load the .env file
load_dotenv()

# Get the API key from the environment variable
API_KEY = os.getenv("CONGRESS_API_KEY")
print(API_KEY)
# Out:
# X1UNYZvcxVhdmRxfZ1re1aES4sfwpfY77lcr8EwD

# %%
bills = []

# Define the API endpoint and parameters
BASE_URL = "https://api.congress.gov/v3"
endpoint = "/bill"
congresses = [i for i in range(106, 120)] # year 2000-2025
bill_types = ["hr", "s", "hjres", "sjres"] # house of reps, senate, house joint res, senate joint res
params = {"api_key" : API_KEY,
          "limit" : 1} # 250 is max

# %%
import json

# get counts for each billl type in a given congress
for c in congresses:
    congress = f"/{c}"
    for b_t in bill_types:
        bill_type = f"/{b_t}"
        url = f"{BASE_URL}{endpoint}{congress}{bill_type}"
        response = requests.get(url, params=params)
        r_json = json.loads(response.text)
        total_bills_in_bill_type = r_json["pagination"]["count"]

        for i in range(1, total_bills_in_bill_type + 1):
            bill_url = f"{BASE_URL}{endpoint}{congress}{bill_type}/{i}"
            response = requests.get(bill_url, params=params)
            
            actions_url = f"{BASE_URL}{endpoint}{congress}{bill_type}/{i}/actions"
            response = requests.get(actions_url, params=params)

            bill_text_url = f"{BASE_URL}{endpoint}{congress}{bill_type}/{i}/actions" # change this to get bill text
            response = requests.get(actions_url, params=params)
            print(response.text)
            break
# Out:
# {
#     "bill": {
#         "actions": {
#             "count": 4,
#             "url": "https://api.congress.gov/v3/bill/106/hr/1/actions?format=json"
#         },
#         "committees": {
#             "count": 1,
#             "url": "https://api.congress.gov/v3/bill/106/hr/1/committees?format=json"
#         },
#         "congress": 106,
#         "introducedDate": "1999-03-01",
#         "latestAction": {
#             "actionDate": "1999-03-02",
#             "text": "Referred to the Subcommittee on Social Security."
#         },
#         "number": "1",
#         "originChamber": "House",
#         "originChamberCode": "H",
#         "policyArea": {
#             "name": "Social Welfare"
#         },
#         "sponsors": [
#             {
#                 "bioguideId": "H000323",
#                 "district": 14,
#                 "firstName": "J.",
#                 "fullName": "Rep. Hastert, J. Dennis [R-IL-14]",
#                 "isByRequest": "N",
# ...

# %%
import json
# Define the API endpoint and parameters
BASE_URL = "https://api.congress.gov/v3"
endpoint = "/bill"

params = {"api_key" : API_KEY}
url = f"{BASE_URL}{endpoint}/117/hr/1/text"
response = requests.get(url, params=params)
r_json = json.loads(response.text)
# print(r_json)
for i in r_json["textVersions"]:
    print(i)
    print()
# response = requests.get(r_json["textVersions"][0]["formats"][0]["url"], params=params)

# print(response)
# print(response.text)
# Out:
# {'date': '2021-03-11T05:00:00Z', 'formats': [{'type': 'Formatted Text', 'url': 'https://www.congress.gov/117/bills/hr1/BILLS-117hr1rds.htm'}, {'type': 'PDF', 'url': 'https://www.congress.gov/117/bills/hr1/BILLS-117hr1rds.pdf'}, {'type': 'Formatted XML', 'url': 'https://www.congress.gov/117/bills/hr1/BILLS-117hr1rds.xml'}], 'type': 'Received in Senate'}
#
# {'date': '2021-03-03T05:00:00Z', 'formats': [{'type': 'Formatted Text', 'url': 'https://www.congress.gov/117/bills/hr1/BILLS-117hr1eh.htm'}, {'type': 'PDF', 'url': 'https://www.congress.gov/117/bills/hr1/BILLS-117hr1eh.pdf'}, {'type': 'Formatted XML', 'url': 'https://www.congress.gov/117/bills/hr1/BILLS-117hr1eh.xml'}], 'type': 'Engrossed in House'}
#
# ...
